# %% [markdown]
# # Dataset
#
# We are doing our analysis on [Spotify Multi-Genre Playlist Data](https://www.kaggle.com/siropo/spotify-multigenre-playlists-data).
# This dataset is a collection of song features taken from Spotify and separated into six broad genres of music.
# Our analysis aims to answer to solve two problems:
# 1. How do you predict the genre of a song based on its features
# 2. What song features are more influential to a particular genre.
#
# It is not a random sampling of songs on Spotify: each song was on a playlist made by the person who collected the dataset.
# However, there is still a wide variety of genres it will work for purposes of our analysis.
#
# The dataset has the following 22 columns:
#
# 1. Artist Name
# 2. Song Name
# 3. Popularity: value from 1 to 100 that represents the song's popularity (magically determined by Spotify)
# 4. Genres: a detailed list of the genres for each artist
# 5. Playlist: the name of the playlist each song came from
# 6. Danceability
# 7. Energy
# 8. Key
# 9. Loudness
# 9. Mode
# 10. Speechiness
# 11. Acousticness
# 12. Instrumentalness
# 13. Liveness
# 14. Valence
# 15. Tempo
# 16. ID
# 17. URI
# 18. HRef
# 19. Analysis_url
# 19. Duration_Ms
# 20. Time-Signature
#
# ## Loading the dataset
#
# The dataset is broken into 6 files, with each file containing the songs from a single genre of music.
# Here, we load the files into memory and combine them into one dataset.
# We also drop the playlist, ID, URI, HRef, and Analysis_url columns because they are not relevant for our analysis.
# Since we will be combining all of the songs into a single dataset, we also have to add another column containing the genre of each song.

# %%
import pandas as pd

def load_dataset(music_genre):
    # First, we read the genre dataset into memory
    # Then we drop all of the columns we don't need
    # and finally we add the genre column and return it 
    return pd.read_csv(f'{music_genre}_music_data.csv').drop(columns=['Playlist', 'id', 'uri', 'track_href', 'analysis_url']).assign(genre=music_genre)

alternative = load_dataset('alternative')
blues = load_dataset('blues')
hiphop = load_dataset('hiphop')
indie_alt = load_dataset('indie_alt')
metal = load_dataset('metal')
pop = load_dataset('pop')
rock = load_dataset('rock')
    
dataset = pd.concat([alternative, blues, hiphop, indie_alt, metal, pop, rock])

# %% [markdown]
# ## Dataset Meta Analysis
#
# Before analysing our dataset, we want to figure out what we are working with regards to the number of songs in each genre and the missing values.

# %%
def inspect_dataset_meta(music_genre):
    print('Genre:', music_genre)
    print('Number of songs:', len(dataset[dataset['genre'] == music_genre]))
    # thanks to Stack Overflow user piRSquared and their answer to this question:
    # https://stackoverflow.com/a/38733583
    print('Number of missing values:', (dataset[dataset['genre'] == music_genre].isna()).to_numpy().sum(), '\n')

genres = ['alternative', 'blues', 'hiphop', 'indie_alt', 'metal', 'pop', 'rock']

for genre in genres:
    inspect_dataset_meta(genre)
    
print('Number of songs in dataset:', len(dataset))
# Out:
# Genre: alternative
# Number of songs: 2160
# Number of missing values: 0
#
# Genre: blues
# Number of songs: 2050
# Number of missing values: 0
#
# Genre: hiphop
# Number of songs: 2581
# Number of missing values: 0
#
# Genre: indie_alt
# Number of songs: 4338
# Number of missing values: 0
#
# Genre: metal
# Number of songs: 3045
# Number of missing values: 0
#
# Genre: pop
# Number of songs: 3831
# Number of missing values: 0
#
# Genre: rock
# Number of songs: 8747
# Number of missing values: 0
#
# Number of songs in dataset: 26752

# %% [markdown]
# Fortunately, there are no missing values in this dataset, so we don't have to worry about that.
# There is a disproportionately large number of rock songs, so if we end up building a classifier, it may end up being biased towards rock (that may not be a bad thing, but what do I know? I'm also biased towards rock)
#
# # Basic Data Exploration
#
# In this section, we'll perform a few visualizations and calculate some statistics for our dataset.
#
# ## Boxplots
#
# We have created a box plot for each of the song features that we will be analyzing, and we have broken the plot of each feature into its respective genre.
# This will help us answer Question 2 (what features are most influential for a particular genre) we visually observe the mean and ranges that each genre has for each feature.
# If we find any medians and ranges for one genre that look particularly different than the other genres, we will know that it is a feature that we should investigate.

# %%
import matplotlib.pyplot as plt

def split_attribute_into_genres(att_name):
    return [alternative[att_name], 
            blues[att_name],
            hiphop[att_name],
            indie_alt[att_name],
            metal[att_name],
            pop[att_name],
            rock[att_name]]


for col in dataset.loc[:, 'danceability':'duration_ms']:
    fig, ax = plt.subplots()
    ax.boxplot(split_attribute_into_genres(col))
    ax.set_title(col)
    ax.set_xticklabels(genres)
    plt.show()

# %% [markdown]
# These box plots reveal some interesting patterns for certain songs. Here are our findings:
#
# * The `energy` in metal songs is significantly higher than that for any other song.
# This means that we should investigate using `energy` to differentiate metal songs from other songs.
#
# * Likewise, the `valence` of metal songs is lower than the other genres, so we should investigate using valence to identify metal songs as well.
#
# * Blues has a higher `acousticness` than any other genre.
#
# * Furthermore, the medians and ranges for `acousticness` seem to wildly vary from genre to genre, so we should investigate this property more.
#
# * The interquartile range of `instrumentalness` for hiphop and pop is too small to be seen on the plot,
# so we should investigate that property for identifying pop and hiphop songs.
#
# * `instrumentalness` in general appears to be an interesting property, with some genres having small ranges and others large ranges.
#
# * `Speechiness` is significantly higher in hiphop than it is in any other genre.
#
# * The `tempo` seems to be similar for each genre, so it is probably not a good variable to use for distinguishing genres.
#
# * The same goes for `liveness`
# ## Ridgeline Plots
#      With ridgeline plots its easier to visualize the patterns in features for each of the genres. What we have to note for ridgeline plots however is that not all the features are on the same scale. The features that are on the scale from 0-1, however can be plotted together to possibly show correlation between features. Features with the 0-1 scale include: danceability, energy, mode, speechiness, acousticness, instrumentalness, liveliness, and valence.

# %%
from joypy import joyplot

for col in dataset.loc[:, 'danceability':'duration_ms']:
    joyplot(
        data = dataset,
        by = 'genre',
        column = [col],
    )
    plt.title(col)
    plt.show()

# %%
plt.figure()
joyplot(
    data =  dataset[['danceability', 'energy', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'genre']],
    by='genre',
    column=['danceability', 'energy'],
    legend=True,
    alpha=0.85,
    figsize=(12,8)
)
plt.title('Ridgeline Plot of Danceability and Energy accross Genre', fontsize=20)
plt.show()

plt.figure()
joyplot(
    data =  dataset[['danceability', 'energy', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'genre']],
    by='genre',
    column=['speechiness', 'acousticness', 'instrumentalness'],
    legend=True,
    alpha=0.85,
    figsize=(12,8)
)
plt.title('Ridgeline Plot of Speechiness, Acousticness, Instrumentalness across Genre', fontsize=20)
plt.show()

# %% [markdown]
# The ridgeline plots help to visualize some of the characteristics of each genre of music realized from the boxplots. We can use the ridgeline plots to compare some of the noticeable features to identify more patterns. Here are some of the patterns that we can see from our ridgeline plots:
# * In regards to `energy` and `danceability` we can see that genres with high energy do not directly translate to high danceability. We can see this through Metal, whereas Hiphop has high danceability and a more average energy.
# * For `valence` it's interesting to note that 'Blues' genre has contrary to its historical background has a relatively high valence in comparison to other genres.
# * In the comparison of `speechiness`, `acousticness`, and `instrumentalness` we can see some trends for each of the genre, blues having much higher accousticness, hiphop with higher speechiness and lower instrumentalness.
#
#
# ## Statistics
#
# Now that we have created box plots for each song feature and identified some possible areas of interest, it is time to generate some statistics for those areas.

# %%
def generate_statistical_matrix(statistical_function):
    stat_dict = dict()
    for genre in genres:
        stat_dict[genre] = statistical_function(dataset[dataset['genre'] == genre].loc[:, 'danceability':'duration_ms'])
    
    return pd.DataFrame(stat_dict)

print('####################################')
print('Mean of Each Feature for Each Genre')   
print(generate_statistical_matrix(pd.DataFrame.mean))
print('####################################\n')
print('Standard Deviation of Each Feature for Each Genre')
print(generate_statistical_matrix(pd.DataFrame.std))
print('####################################')
# Out:
# ####################################
# Mean of Each Feature for Each Genre
#                     alternative          blues         hiphop      indie_alt  \
# danceability           0.536953       0.564278       0.733737       0.555842
# energy                 0.693046       0.572964       0.638692       0.661998
# key                    5.355556       5.432683       5.319256       5.383356
# loudness              -7.623776      -9.145411      -7.376902      -8.056145
# mode                   0.658796       0.667805       0.533514       0.656293
# speechiness            0.067556       0.062206       0.235685       0.066785
# acousticness           0.177995       0.399214       0.191144       0.217492
# instrumentalness       0.164318       0.086851       0.022999       0.218268
# liveness               0.188587       0.207691       0.197226       0.187769
# valence                0.513680       0.613717       0.538287       0.494158
# tempo                126.069160     121.604544     118.861744     123.375715
# duration_ms       223880.492130  244535.600976  204539.001162  228327.719225
#
#                           metal            pop           rock
# danceability           0.415496       0.642245       0.502520
# energy                 0.879960       0.609659       0.742130
# key                    5.243678       5.224223       5.259746
# loudness              -5.832565      -6.971849      -6.835121
# mode                   0.581281       0.540329       0.664685
# speechiness            0.089362       0.076090       0.062246
# acousticness           0.026483       0.307534       0.126006
# instrumentalness       0.199845       0.024984       0.081875
# liveness               0.224378       0.170922       0.206974
# valence                0.326787       0.519968       0.494039
# tempo                127.958087     119.609968     125.783093
# duration_ms       269403.029885  203472.993996  239448.689151
# ####################################
#
# Standard Deviation of Each Feature for Each Genre
#                    alternative         blues        hiphop     indie_alt  \
# danceability          0.157916      0.139426      0.139042      0.163409
# energy                0.212345      0.230567      0.155254      0.214284
# key                   3.569007      3.560343      3.719576      3.576867
# loudness              3.831861      3.884655      2.779710      3.720799
# mode                  0.474223      0.471115      0.498972      0.474999
# speechiness           0.065370      0.055037      0.136712      0.067568
# acousticness          0.263960      0.332564      0.207103      0.287362
# instrumentalness      0.292144      0.208993      0.121938      0.322475
# liveness              0.141501      0.183476      0.155670      0.145036
# valence               0.234666      0.207301      0.218977      0.248266
# tempo                29.027706     31.716712     29.559240     27.842065
# duration_ms       61890.074918  88052.655702  61730.306721  75147.376344
#
#                          metal           pop          rock
# danceability          0.129641      0.137085      0.136813
# energy                0.141152      0.191789      0.192597
# key                   3.507791      3.618577      3.512935
# loudness              2.530493      2.537035      3.177930
# mode                  0.493430      0.498436      0.472127
# speechiness           0.060497      0.075119      0.051713
# acousticness          0.112555      0.290344      0.217552
# instrumentalness      0.310738      0.114642      0.207497
# liveness              0.164672      0.124818      0.165069
# valence               0.191747      0.223385      0.222843
# tempo                30.098643     27.414103     29.663686
# duration_ms       87283.504560  43171.051539  89575.629048
# ####################################

# %% [markdown]
# It is harder to draw any good conclusions based solely off of the mean and standard deviation of each feature.
# These values do more to back up the patterns shown in the box plots, and to reveal some information that was obscured by the limitations of the box plots.
#
# * Possibly the best revelation is the connection between energy and metal. The average energy for metal songs over 1 standard deviation higher than the average energy for most other genres.
#
# * The mean instrumentalness of pop and hiphop are very similar, and they both have small standard deviations.
# This supports the hypothesis that instrumentalness would be a good candidate for identifying pop and hiphop songs.
# However, their means are close to the means of other genres (especially ones with a higher standard deviation) so we will have to see how much it affects models in-pratice.
#
#
# # Analysis
#
# ## Logistic Regression
#
# We will be using logistic regression to help answer the question: what song features are more influential to a particular genre?
# We'll accomplish this by creating a logistic model for each genre that determines whether a song is in that particular genre.
# We'll then analyze its coefficients to determine which ones are statistically significant.
# Since we are training each model in a '1 genre vs every other genre', the significant features are useful for identifying each specific genre.
#
# For example, the logistic regression for metal music will output either 1: a given song is metal, or 0: a given song is not metal.
# We expect that its energy coefficient will be statistically significant for the logistic regression due to the prior analysis that showed that metal songs typically have higher energy than non-metal songs.
#
# The following code builds a logistic regression for each genre. Since we are building each model as a '1 genre vs all other genres',
# we train each model using every song from a single genre, and then a random sample of songs from every other genre.
# We want to make our model someone balanced, so we have the same number of songs from a single genre as we do from every other genre (i.g., the metal model was trained using 3045 metal songs and 3045 non-metal songs).
# We didn't break our data into training and testing sets or use some sort of cross-validation because we don't really care about the performance of our model.
# We're not using logistic regression to build a classifier here, we're using it to identify which variables are significant for distinguishing genres.

# %%
import statsmodels.api as sm

def build_regression(genre_name):
    # collect all of the songs that belong to the given genre (and ignore any columns that aren't song features)
    X_same_genre = dataset[dataset['genre'] == genre_name].loc[:, 'danceability':'duration_ms']
    # Collect the songs that don't belong to the given genre (collect only a random sample to ensure a balanced dataset)
    X_different_genre = dataset[dataset['genre'] != genre_name].loc[:,'danceability':'duration_ms'].sample(n=len(X_same_genre))
    
    X_train = pd.concat([X_same_genre, X_different_genre], ignore_index=True)
    
    # for the Y data, we just need to make a dataframe of all 1s or all 0s with the same length as the X data
    Y_same_genre = pd.DataFrame(index=range(len(X_same_genre)), columns=['genre']).assign(genre=1)
    Y_different_genre = pd.DataFrame(index=range(len(X_same_genre)), columns=['genre']).assign(genre=0)

    Y_train = pd.concat([Y_same_genre,Y_different_genre], ignore_index=True)

    return sm.Logit(Y_train, X_train).fit()

# %% [markdown]
# ### Alternative Music Regression
#
# Below is a summary of the logistic regression model for alternative music.

# %%
build_regression('alternative').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.668850
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                 4320
# Model:                          Logit   Df Residuals:                     4308
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                 0.03505
# Time:                        08:26:43   Log-Likelihood:                -2889.4
# converged:                       True   LL-Null:                       -2994.4
# Covariance Type:            nonrobust   LLR p-value:                 6.457e-39
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability        -0.3719      0.197     -1.885      0.059      -0.759       0.015
# energy               0.0186      0.197      0.094      0.925      -0.368       0.405
# key                  0.0094      0.009      1.081      0.280      -0.008       0.027
# loudness            -0.0524      0.012     -4.349      0.000      -0.076      -0.029
# mode                 0.0956      0.065      1.464      0.143      -0.032       0.224
# speechiness         -3.5255      0.449     -7.854      0.000      -4.405      -2.646
# acousticness        -0.6710      0.158     -4.254      0.000      -0.980      -0.362
# instrumentalness     0.7268      0.128      5.674      0.000       0.476       0.978
# liveness            -0.3820      0.214     -1.789      0.074      -0.801       0.037
# valence              0.4454      0.157      2.832      0.005       0.137       0.754
# tempo                0.0037      0.001      3.631      0.000       0.002       0.006
# duration_ms      -2.784e-06    4.5e-07     -6.189      0.000   -3.67e-06    -1.9e-06
# ====================================================================================
# """

# %% [markdown]
# With P > .05, we can see that key, liveness, and tempo are not statistically relevant for classifying
# alternative music. Given the boxplots from the EDA section, this was to be expected.
# Key and energy are also insignificant for identifying alternative songs.
#
# ### Blues Music Regression
#
# Below is a summary of the logistic regression model for blues.

# %%
build_regression('blues').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.530999
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                 4100
# Model:                          Logit   Df Residuals:                     4088
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                  0.2339
# Time:                        08:26:43   Log-Likelihood:                -2177.1
# converged:                       True   LL-Null:                       -2841.9
# Covariance Type:            nonrobust   LLR p-value:                1.839e-278
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability        -2.8991      0.254    -11.419      0.000      -3.397      -2.401
# energy              -2.6972      0.242    -11.146      0.000      -3.172      -2.223
# key                  0.0076      0.010      0.727      0.467      -0.013       0.028
# loudness             0.0125      0.014      0.900      0.368      -0.015       0.040
# mode                -0.0127      0.078     -0.163      0.871      -0.166       0.141
# speechiness         -4.3529      0.538     -8.084      0.000      -5.408      -3.298
# acousticness         2.0448      0.162     12.590      0.000       1.726       2.363
# instrumentalness    -0.5840      0.181     -3.235      0.001      -0.938      -0.230
# liveness             0.7843      0.226      3.478      0.001       0.342       1.226
# valence              4.4077      0.212     20.831      0.000       3.993       4.822
# tempo               -0.0014      0.001     -1.211      0.226      -0.004       0.001
# duration_ms       3.405e-06   4.82e-07      7.067      0.000    2.46e-06    4.35e-06
# ====================================================================================
# """

# %% [markdown]
# Mode, loudness, and key are all statistically insignificant for distinguishing blues songs.
# Interestingly enough, tempo and liveness are significant.
#
# ### Hip Hop Music Regression
#
# Below is a summary of the logistic regression model for hip hop.

# %%
build_regression('hiphop').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.337855
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                 5162
# Model:                          Logit   Df Residuals:                     5150
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                  0.5126
# Time:                        08:26:43   Log-Likelihood:                -1744.0
# converged:                       True   LL-Null:                       -3578.0
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability         6.7047      0.286     23.419      0.000       6.144       7.266
# energy              -4.6239      0.297    -15.557      0.000      -5.206      -4.041
# key                 -0.0163      0.012     -1.351      0.177      -0.040       0.007
# loudness             0.1493      0.019      8.049      0.000       0.113       0.186
# mode                -0.3787      0.088     -4.314      0.000      -0.551      -0.207
# speechiness         15.4038      0.526     29.261      0.000      14.372      16.436
# acousticness        -0.8578      0.207     -4.148      0.000      -1.263      -0.452
# instrumentalness    -1.0053      0.265     -3.792      0.000      -1.525      -0.486
# liveness             1.1249      0.283      3.969      0.000       0.569       1.680
# valence             -0.9624      0.213     -4.526      0.000      -1.379      -0.546
# tempo               -0.0085      0.001     -5.845      0.000      -0.011      -0.006
# duration_ms      -1.043e-06   6.94e-07     -1.503      0.133    -2.4e-06    3.17e-07
# ====================================================================================
# """

# %% [markdown]
# Surprisingly, only the key is insignificant for identifying hip hop songs. The instrumentalness is close, which we find interesting
# given that it was an area of interest in the boxplot analysis. Further analysis will be needed to show how influential it really is.
#
# ### Indie Alt Music Regression
#
# Below is a summary of the logistic regression model for indie alt music.

# %%
build_regression('indie_alt').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.644503
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                 8676
# Model:                          Logit   Df Residuals:                     8664
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                 0.07018
# Time:                        08:26:43   Log-Likelihood:                -5591.7
# converged:                       True   LL-Null:                       -6013.7
# Covariance Type:            nonrobust   LLR p-value:                6.474e-174
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability         0.6399      0.144      4.457      0.000       0.359       0.921
# energy              -0.6418      0.142     -4.520      0.000      -0.920      -0.364
# key                  0.0065      0.006      1.026      0.305      -0.006       0.019
# loudness            -0.0314      0.009     -3.489      0.000      -0.049      -0.014
# mode                 0.1480      0.047      3.138      0.002       0.056       0.240
# speechiness         -3.6214      0.320    -11.323      0.000      -4.248      -2.995
# acousticness        -0.2339      0.109     -2.149      0.032      -0.447      -0.021
# instrumentalness     1.9596      0.097     20.099      0.000       1.769       2.151
# liveness            -0.1260      0.152     -0.828      0.408      -0.424       0.172
# valence              0.1709      0.112      1.521      0.128      -0.049       0.391
# tempo                0.0021      0.001      2.802      0.005       0.001       0.004
# duration_ms      -2.382e-06    3.1e-07     -7.691      0.000   -2.99e-06   -1.77e-06
# ====================================================================================
# """

# %% [markdown]
# Liveness and tempo are, as expected, insignificant for indie alt music.
# The key is also not useful, which has been the case for every other genre of music.
#
# ### Metal Music Regression
#
# Below is a summary of the logistic regression model for metal music.

# %%
build_regression('metal').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.412259
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                 6090
# Model:                          Logit   Df Residuals:                     6078
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                  0.4052
# Time:                        08:26:43   Log-Likelihood:                -2510.7
# converged:                       True   LL-Null:                       -4221.3
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability        -4.3257      0.262    -16.514      0.000      -4.839      -3.812
# energy               6.2700      0.251     24.936      0.000       5.777       6.763
# key                 -0.0426      0.010     -4.249      0.000      -0.062      -0.023
# loudness            -0.0411      0.016     -2.635      0.008      -0.072      -0.011
# mode                -0.3822      0.073     -5.258      0.000      -0.525      -0.240
# speechiness         -3.0900      0.609     -5.073      0.000      -4.284      -1.896
# acousticness        -2.2414      0.284     -7.899      0.000      -2.798      -1.685
# instrumentalness     0.6734      0.143      4.708      0.000       0.393       0.954
# liveness            -0.4862      0.216     -2.249      0.024      -0.910      -0.063
# valence             -3.8889      0.197    -19.755      0.000      -4.275      -3.503
# tempo               -0.0085      0.001     -7.259      0.000      -0.011      -0.006
# duration_ms       2.019e-06   4.35e-07      4.646      0.000    1.17e-06    2.87e-06
# ====================================================================================
# """

# %% [markdown]
# Interestingly enough, every feature is significant for identifying metal music, even variables such as liveness, tempo, and key,
# which are not significant for other genres. More analysis needs to be done to see which features are the most and least infuential to the regression.
#
# ### Pop Music Regression
#
# Below is a summary of the logistic regression model for pop music.

# %%
build_regression('pop').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.534918
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                 7662
# Model:                          Logit   Df Residuals:                     7650
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                  0.2283
# Time:                        08:26:43   Log-Likelihood:                -4098.5
# converged:                       True   LL-Null:                       -5310.9
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability         5.6131      0.194     28.912      0.000       5.233       5.994
# energy              -1.6670      0.186     -8.976      0.000      -2.031      -1.303
# key                 -0.0023      0.008     -0.304      0.761      -0.017       0.013
# loudness             0.1786      0.013     14.274      0.000       0.154       0.203
# mode                -0.2901      0.055     -5.279      0.000      -0.398      -0.182
# speechiness         -4.1259      0.347    -11.907      0.000      -4.805      -3.447
# acousticness         2.1881      0.128     17.155      0.000       1.938       2.438
# instrumentalness    -2.2218      0.186    -11.952      0.000      -2.586      -1.857
# liveness            -0.5051      0.196     -2.580      0.010      -0.889      -0.121
# valence             -0.6340      0.141     -4.487      0.000      -0.911      -0.357
# tempo                0.0043      0.001      4.863      0.000       0.003       0.006
# duration_ms      -4.437e-06   5.15e-07     -8.622      0.000   -5.45e-06   -3.43e-06
# ====================================================================================
# """

# %% [markdown]
# For pop music, the key is the only variable that isn't useful for the logistic model, although liveness is close to being stastistically insignificant as well.
#
# ### Rock Music Regression
#
# Below is a summary of the logistic regression model for rock and roll.

# %%
build_regression('rock').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.619643
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  genre   No. Observations:                17494
# Model:                          Logit   Df Residuals:                    17482
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 18 Nov 2021   Pseudo R-squ.:                  0.1060
# Time:                        08:26:43   Log-Likelihood:                -10840.
# converged:                       True   LL-Null:                       -12126.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# danceability        -2.5950      0.111    -23.391      0.000      -2.812      -2.378
# energy               1.2013      0.103     11.669      0.000       1.000       1.403
# key                  0.0038      0.005      0.825      0.409      -0.005       0.013
# loudness            -0.0587      0.007     -9.002      0.000      -0.072      -0.046
# mode                 0.2219      0.034      6.546      0.000       0.155       0.288
# speechiness         -7.0815      0.297    -23.825      0.000      -7.664      -6.499
# acousticness        -1.1224      0.085    -13.260      0.000      -1.288      -0.957
# instrumentalness    -1.4602      0.075    -19.486      0.000      -1.607      -1.313
# liveness             0.2703      0.106      2.554      0.011       0.063       0.478
# valence              0.5862      0.084      7.014      0.000       0.422       0.750
# tempo                0.0014      0.001      2.658      0.008       0.000       0.002
# duration_ms       1.258e-06   2.15e-07      5.853      0.000    8.37e-07    1.68e-06
# ====================================================================================
# """

# %% [markdown]
# Key, liveness, and tempo are not useful for distinguishing rock and roll music, no surprises here.
#
# ### Analysis of Regressions
#
# Key, liveness, and tempo were the three most commonly insignificant varaibles in our regressions.
# However, due to the limit of logistic regression, we don't yet know what variables are the most significant.
# We had hoped that this analysis would do a better job of weeding out variables that didn't greatly influence the genre,
# but after actually creating these logistic models, that was not the case.
#
#
# The main issue is that a summary of coefficients for logistic regression can only tell us what features are *not* significant for identifying
# a particular genre. Unfortunately, it cannot tell us what the most important features are.
# In the next round of analysis, we will perform forward and backward feature selection.
# This will identify which features cause the most change in the logistic model, and thereby influence each genre of music the most.

# %% [markdown]
# ## K-means clustering of music features

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np

clustering_df = dataset[['danceability','energy','key','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
clustering_df.head()
scaler = StandardScaler()
X_std = scaler.fit_transform(clustering_df)

pca = PCA(2)
df = pca.fit_transform(X_std) 
 
kmeans = KMeans(n_clusters= 10)
 
#predict the labels of clusters.
label = kmeans.fit_predict(df)
 
#Getting unique labels
u_labels = np.unique(label)
 
#plotting the results:
for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)
plt.legend()
plt.show()
